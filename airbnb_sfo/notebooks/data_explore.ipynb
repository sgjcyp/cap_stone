# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import  mean_squared_error, r2_score
from collections import Counter

import statsmodels.api as sm

# %%
cal = pd.read_csv('calendar.csv.gz')
listd = pd.read_csv('listings.csv.gz')
lists = pd.read_csv('listings.csv')
revs = pd.read_csv('reviews.csv.gz')
nhood = pd.read_csv('neighbourhoods.csv')
purelst = pd.read_csv('listings.csv.gz')

# %%
# pd.set_option('display.max_colu?mns', 96)
pd.set_option('display.max_rows', 96)

# %%
#CLEANUP incoming dataframes

listd_drop_cols = ['scrape_id','last_scraped','experiences_offered','thumbnail_url','medium_url','xl_picture_url',\
                   'host_name','host_location','neighbourhood_group_cleansed','square_feet',\
                   'maximum_nights','is_business_travel_ready']

# listd_numc_cols
# listd_catz_cols

print(len(listd.columns), len(listd_drop_cols))
listd.drop(listd_drop_cols,axis=1,inplace=True )
print(len(listd.columns), len(listd_drop_cols))
# Out:
# 96 12
# 84 12

# %% [markdown]
# # ALL TRANSFORMATIONS FUNCTIONS  :

# %%
print(cal.date.min(),cal.date.max())
print(revs.date.min(),revs.date.max())
# print(lists.last_review.min(),lists.last_review.max())

# %%
# tmp=listd.copy() # Create a new copy of the existing dataframe otherwise it is only by reference
# tmp.head().T

# %%
def price_xform(dframe,colname):
    dframe[colname]=dframe[colname].str.replace('$','')
    dframe[colname]=dframe[colname].str.replace(',','')
    dframe[colname]=pd.to_numeric(dframe[colname])
#     return(dframe)

# %%
def cat_rename(dframe,colname,src,tgt):
    dframe[colname]=dframe[colname].str.replace(src,tgt)
#     dframe[colname]=dframe[colname].str.replace(',','')
#     dframe[colname]=pd.to_numeric(dframe[colname])
#     return(dframe)

# %%
def create_dummies(dframe,colname):
#     dfnew=dframe.copy()
    dframe=pd.get_dummies(data=dframe, columns=[colname])# create dummies and drop the parent column
    dframe.drop(columns=[dframe.columns[-1]],inplace=True) #dropped the last column from the add dummies
    return dframe

# %%
#Impute Null Rows based on the specified column
def impute_nullrows(dframe,colname):
    print(dframe[colname].isnull().sum())
    dftmp=dframe[~dframe[colname].isnull()]   # remove nulls from one column
    print(dftmp[colname].isnull().sum())
    return dftmp

# %% [markdown]
# # TRANSFORM ACTIONS

# %%
# Convert to Booleans
listd['host_is_superhost'] = listd.apply(lambda x:  x.host_is_superhost=='t', axis= 1)
listd['host_has_profile_pic'] = listd.apply(lambda x:  x.host_has_profile_pic=='t', axis= 1)
listd['host_identity_verified'] = listd.apply(lambda x:  x.host_identity_verified=='t', axis= 1)
listd['instant_bookable'] = listd.apply(lambda x:  x.instant_bookable=='t', axis= 1)

# %%
#Transform all the price columns to remove "$" and ","

price_xform(listd,'price')
price_xform(listd,'weekly_price')
price_xform(listd,'monthly_price')
price_xform(listd,'security_deposit')
price_xform(listd,'cleaning_fee')
price_xform(listd,'extra_people')

# %%
#Transform the room_type . to create a meaningful name and create dummies

cat_rename(listd,'room_type','Entire home/apt','full')
cat_rename(listd,'room_type','Private room','pvt')
cat_rename(listd,'room_type','Shared room','shared')

listd=create_dummies(listd,'room_type')
# listd=pd.get_dummies(data=listd, columns=['room_type'])  # create dummies and drop the parent column
# listd.drop(columns=[listd.columns[-1]],inplace=True)  #dropped the last column from the add dummies

# %%
#Transform the bed_type . to create a meaningful name and create dummies
listd['bed_type'] = listd.apply(lambda x: x.bed_type=='Real Bed', axis=1)

# %%
#Put a count on amenities,   IF it does not work, pick the most important feature
listd['amentcnt'] =   listd.apply(lambda x: len(x.amenities.split(",")), axis=1)

# %%
#!!! APPLY the same for the test data also
#Impute the to remove the rows with no zipcode.  !!! APPLY the same for the test data also
listd=listd[~listd['zipcode'].isnull()]   # remove nulls from one column

# %%
#Impute the null values with meaningful data

listd['cleaning_fee']=listd['cleaning_fee'].fillna(0)
listd['review_scores_cleanliness'] = listd['review_scores_cleanliness'].fillna(listd.review_scores_cleanliness.mean())

listd['review_scores_location'] = listd['review_scores_location'].fillna(listd.review_scores_location.mean())
listd['review_scores_value'] = listd['review_scores_value'].fillna(listd.review_scores_value.mean())

# %%
# mask1 = listd['minimum_nights']>7 
# mask2 = listd['minimum_nights']<=32
# maskmid=mask1 & mask2 
# maskmid = (listd['minimum_nights']>7) & (listd['minimum_nights']<=32)
# mask2
# maskmid
listd.loc[listd['minimum_nights']<=7,'min_night_stay'] = 'short'
listd.loc[(listd['minimum_nights']>7) & (listd['minimum_nights']<=32),'min_night_stay'] = 'mid'
listd.loc[listd['minimum_nights']>32,'min_night_stay'] = 'long'
listd=create_dummies(listd,'min_night_stay')

# %%
#Condensing the property_type to sub categories

listd.loc[listd['property_type']=='Apartment', 'ppt_condensed'] = 'apt'
listd.loc[listd['property_type']=='Condominium', 'ppt_condensed'] = 'apt'
listd.loc[listd['property_type']=='Guest suite', 'ppt_condensed'] = 'apt'
listd.loc[listd['property_type']=='Townhouse', 'ppt_condensed'] = 'apt'
listd.loc[listd['property_type']=='Guesthouse', 'ppt_condensed'] = 'apt'
listd.loc[listd['property_type']=='Tiny house', 'ppt_condensed'] = 'apt'
listd.loc[listd['property_type']=='Timeshare', 'ppt_condensed'] = 'apt'

listd.loc[listd['property_type']=='Serviced apartment', 'ppt_condensed'] = 'aptspl'
listd.loc[listd['property_type']=='Bed and breakfast', 'ppt_condensed'] = 'aptspl'
listd.loc[listd['property_type']=='Treehouse', 'ppt_condensed'] = 'aptspl'
listd.loc[listd['property_type']=='Cabin', 'ppt_condensed'] = 'aptspl'

listd.loc[listd['property_type']=='Bus', 'ppt_condensed'] = 'auto'
listd.loc[listd['property_type']=='Boat', 'ppt_condensed'] = 'auto'
listd.loc[listd['property_type']=='Camper/RV', 'ppt_condensed'] = 'auto'

listd.loc[listd['property_type']=='Hostel', 'ppt_condensed'] = 'hostel'

listd.loc[listd['property_type']=='Boutique hotel', 'ppt_condensed'] = 'hotel'
listd.loc[listd['property_type']=='Hotel', 'ppt_condensed'] = 'hotel'
listd.loc[listd['property_type']=='Resort', 'ppt_condensed'] = 'hotel'
listd.loc[listd['property_type']=='Aparthotel', 'ppt_condensed'] = 'hotel'

listd.loc[listd['property_type']=='House', 'ppt_condensed'] = 'house'
listd.loc[listd['property_type']=='Bungalow', 'ppt_condensed'] = 'house'
listd.loc[listd['property_type']=='Cottage', 'ppt_condensed'] = 'house'
listd.loc[listd['property_type']=='Villa', 'ppt_condensed'] = 'house'

listd.loc[listd['property_type']=='Other', 'ppt_condensed'] = 'other'

listd.loc[listd['property_type']=='Loft', 'ppt_condensed'] = 'room'

listd=create_dummies(listd,'ppt_condensed')

# %%
listd=create_dummies(listd,'zipcode')

# %%
#imputing some more missing values

listd['cleaning_fee'].fillna(0, inplace=True)
listd['beds'].fillna(0, inplace=True)
listd['bathrooms'].fillna(0, inplace=True)

# %%
listd.shape
# Out:
# (4669, 122)

# %%
#Imputed the rows with price is equal to zero
listd=listd[listd.price>0]
listd.shape
# Out:
# (4662, 122)

# %%
# lreg_cols = ['price','weekly_price','cleaning_fee','accommodates','bedrooms','beds',\
#              'bathrooms','guests_included','zipcode']

listd_drop_cols2=['id', 'listing_url', 'name', 'summary', 'space', 'description',\
       'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',\
       'house_rules', 'picture_url', 'host_id', 'host_url', 'host_since',\
       'host_about', 'host_response_time', 'host_response_rate',\
       'host_acceptance_rate', 'host_thumbnail_url',\
       'host_picture_url', 'host_neighbourhood', 'host_listings_count',\
       'host_total_listings_count', 'host_verifications',\
       'host_has_profile_pic', 'street',\
       'neighbourhood', 'neighbourhood_cleansed', 'city', 'state',\
       'market', 'smart_location', 'country_code', 'country', 'latitude',\
       'longitude', 'is_location_exact', 'property_type',\
       'amenities',\
       'weekly_price', 'monthly_price', 'security_deposit',\
       'extra_people', 'minimum_nights', 'calendar_updated',\
       'has_availability', 'availability_30', 'availability_60',\
       'availability_90', 'availability_365', 'calendar_last_scraped',\
       'number_of_reviews', 'first_review', 'last_review',\
       'review_scores_rating', 'review_scores_accuracy',\
       'review_scores_cleanliness', 'review_scores_checkin',\
       'review_scores_communication', 'review_scores_location',\
       'review_scores_value', 'requires_license', 'license',\
       'jurisdiction_names', 'instant_bookable', 'cancellation_policy',\
       'require_guest_profile_picture', 'require_guest_phone_verification',\
       'calculated_host_listings_count', 'reviews_per_month']
listd.drop(listd_drop_cols2,axis=1,inplace=True )

# %%
listd.columns
# Out:
# Index(['host_is_superhost', 'host_identity_verified', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'price', 'cleaning_fee',
#        'guests_included', 'room_type_full', 'room_type_pvt', 'amentcnt',
#        'min_night_stay_long', 'min_night_stay_mid', 'ppt_condensed_apt',
#        'ppt_condensed_aptspl', 'ppt_condensed_auto', 'ppt_condensed_hostel',
#        'ppt_condensed_hotel', 'ppt_condensed_house', 'ppt_condensed_other',
#        'zipcode_94014.0', 'zipcode_94015.0', 'zipcode_94102.0',
#        'zipcode_94103.0', 'zipcode_94104.0', 'zipcode_94105.0',
#        'zipcode_94107.0', 'zipcode_94108.0', 'zipcode_94109.0',
#        'zipcode_94110.0', 'zipcode_94111.0', 'zipcode_94112.0',
#        'zipcode_94114.0', 'zipcode_94115.0', 'zipcode_94116.0',
#        'zipcode_94117.0', 'zipcode_94118.0', 'zipcode_94121.0',
#        'zipcode_94122.0', 'zipcode_94123.0', 'zipcode_94124.0',
#        'zipcode_94127.0', 'zipcode_94129.0', 'zipcode_94131.0',
#        'zipcode_94132.0', 'zipcode_94133.0', 'zipcode_94134.0',
#        'zipcode_94158.0'],
#       dtype='object')

# %%
listd.shape
purelst[purelst.price =='$0.00'].T
# purelst.head().T
# Out:
#                                                                                3553  \
# id                                                                         20331804
# listing_url                                   https://www.airbnb.com/rooms/20331804
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                              Cozy Victorian Bedroom in Mission
# summary                           Steps from Mission St, this private room provi...
# space                             This bedroom has a unique Victorian San Franci...
# description                       Steps from Mission St, this private room provi...
# experiences_offered                                                            none
# neighborhood_overview             The apartment is located in the La Lengua Area...
# notes                                                                           NaN
# transit                           Being on Mission St., you have direct access t...
# access                            Guests can access all areas inside the apartme...
# interaction                       My wife (Marie), my son (Jacob - 2 yrs), and I...
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/b6c29d7f-4...
# xl_picture_url                                                                  NaN
# host_id                                                                    17536951
# host_url                                 https://www.airbnb.com/users/show/17536951
# host_name                                                                       Rob
# host_since                                                               2014-07-02
# host_location                              San Francisco, California, United States
# host_about                        My wife and I have lived in Asia for a long ti...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 t
# host_thumbnail_url                https://a0.muscache.com/im/pictures/fe57912d-3...
# host_picture_url                  https://a0.muscache.com/im/pictures/fe57912d-3...
# host_neighbourhood                                                   Bernal Heights
# host_listings_count                                                               5
# host_total_listings_count                                                         5
# host_verifications                ['email', 'phone', 'reviews', 'jumio', 'govern...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Bernal Heights
# neighbourhood_cleansed                                               Bernal Heights
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94110
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7448
# longitude                                                                   -122.42
# is_location_exact                                                                 t
# property_type                                                           Condominium
# room_type                                                              Private room
# accommodates                                                                      1
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              1
# bed_type                                                                   Real Bed
# amenities                         {TV,"Cable TV",Wifi,Kitchen,Heating,Washer,Dry...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                            $200.00
# cleaning_fee                                                                 $50.00
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                   21
# calendar_updated                                                              today
# has_availability                                                                  t
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   0
# availability_365                                                                  0
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                 8
# first_review                                                             2017-09-14
# last_review                                                              2017-10-19
# review_scores_rating                                                             95
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                                 STR-0001202
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  t
# is_business_travel_ready                                                          f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    5
# reviews_per_month                                                              0.81
#
#                                                                                3605  \
# id                                                                         20625135
# listing_url                                   https://www.airbnb.com/rooms/20625135
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                                    Cheap. Safe and Comfortable
# summary                           Welcome to hacker/co-living house for entrepre...
# space                             This specific room with the twin beds has 2 be...
# description                       Welcome to hacker/co-living house for entrepre...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/0bc5515d-5...
# xl_picture_url                                                                  NaN
# host_id                                                                    21940642
# host_url                                 https://www.airbnb.com/users/show/21940642
# host_name                                                                      Alex
# host_since                                                               2014-09-29
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                              99%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/pictures/ab026665-a...
# host_picture_url                  https://a0.muscache.com/im/pictures/ab026665-a...
# host_neighbourhood                                                     Mid-Wilshire
# host_listings_count                                                              27
# host_total_listings_count                                                        27
# host_verifications                ['email', 'phone', 'facebook', 'google', 'revi...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Crocker Amazon
# neighbourhood_cleansed                                               Crocker Amazon
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94112
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7129
# longitude                                                                  -122.438
# is_location_exact                                                                 t
# property_type                                                                 House
# room_type                                                               Shared room
# accommodates                                                                      2
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              2
# bed_type                                                                   Real Bed
# amenities                         {Wifi,"Air conditioning",Kitchen,"Indoor firep...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                              $0.00
# cleaning_fee                                                                  $0.00
# guests_included                                                                   1
# extra_people                                                                 $45.00
# minimum_nights                                                                   30
# maximum_nights                                                                  180
# calendar_updated                                                        2 weeks ago
# has_availability                                                                  t
# availability_30                                                                   2
# availability_60                                                                   2
# availability_90                                                                   2
# availability_365                                                                 86
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                 6
# first_review                                                             2018-02-12
# last_review                                                              2018-06-01
# review_scores_rating                                                             83
# review_scores_accuracy                                                            8
# review_scores_cleanliness                                                         7
# review_scores_checkin                                                             8
# review_scores_communication                                                       8
# review_scores_location                                                            7
# review_scores_value                                                               8
# requires_license                                                                  t
# license                                                   City registration pending
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  t
# is_business_travel_ready                                                          f
# cancellation_policy                                     strict_14_with_grace_period
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              1.25
#
#                                                                                3606  \
# id                                                                         20626299
# listing_url                                   https://www.airbnb.com/rooms/20626299
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                      Coliving in a quiet and safe neighborhood
# summary                           Welcome to hacker/co-living house for entrepre...
# space                             The space This specific room with the twin bed...
# description                       Welcome to hacker/co-living house for entrepre...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/10d0858b-d...
# xl_picture_url                                                                  NaN
# host_id                                                                    21940642
# host_url                                 https://www.airbnb.com/users/show/21940642
# host_name                                                                      Alex
# host_since                                                               2014-09-29
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                              99%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/pictures/ab026665-a...
# host_picture_url                  https://a0.muscache.com/im/pictures/ab026665-a...
# host_neighbourhood                                                     Mid-Wilshire
# host_listings_count                                                              27
# host_total_listings_count                                                        27
# host_verifications                ['email', 'phone', 'facebook', 'google', 'revi...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Crocker Amazon
# neighbourhood_cleansed                                               Crocker Amazon
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94112
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7135
# longitude                                                                  -122.439
# is_location_exact                                                                 t
# property_type                                                                 House
# room_type                                                               Shared room
# accommodates                                                                      2
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              2
# bed_type                                                                   Real Bed
# amenities                         {Wifi,"Air conditioning",Kitchen,Heating,Washe...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                              $0.00
# cleaning_fee                                                                  $0.00
# guests_included                                                                   1
# extra_people                                                                 $45.00
# minimum_nights                                                                   30
# maximum_nights                                                                  180
# calendar_updated                                                              today
# has_availability                                                                  t
# availability_30                                                                   3
# availability_60                                                                  33
# availability_90                                                                  63
# availability_365                                                                153
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                12
# first_review                                                             2017-09-06
# last_review                                                              2018-05-29
# review_scores_rating                                                             82
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                             9
# review_scores_communication                                                      10
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                   City Registration Pending
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  f
# is_business_travel_ready                                                          f
# cancellation_policy                                     strict_14_with_grace_period
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              1.19
#
#                                                                                3607  \
# id                                                                         20626447
# listing_url                                   https://www.airbnb.com/rooms/20626447
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                      Room for female close to public transport
# summary                           Welcome to hacker/co-living house for entrepre...
# space                             This specific room with the twin beds has 2 be...
# description                       Welcome to hacker/co-living house for entrepre...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/e20ab1a2-3...
# xl_picture_url                                                                  NaN
# host_id                                                                    21940642
# host_url                                 https://www.airbnb.com/users/show/21940642
# host_name                                                                      Alex
# host_since                                                               2014-09-29
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                              99%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/pictures/ab026665-a...
# host_picture_url                  https://a0.muscache.com/im/pictures/ab026665-a...
# host_neighbourhood                                                     Mid-Wilshire
# host_listings_count                                                              27
# host_total_listings_count                                                        27
# host_verifications                ['email', 'phone', 'facebook', 'google', 'revi...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Crocker Amazon
# neighbourhood_cleansed                                               Crocker Amazon
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94112
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7132
# longitude                                                                  -122.438
# is_location_exact                                                                 t
# property_type                                                                 House
# room_type                                                               Shared room
# accommodates                                                                      2
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              2
# bed_type                                                                   Real Bed
# amenities                         {Wifi,"Air conditioning",Kitchen,Heating,Washe...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                              $0.00
# cleaning_fee                                                                  $0.00
# guests_included                                                                   1
# extra_people                                                                 $45.00
# minimum_nights                                                                   30
# maximum_nights                                                                  180
# calendar_updated                                                        3 weeks ago
# has_availability                                                                  t
# availability_30                                                                   0
# availability_60                                                                  24
# availability_90                                                                  54
# availability_365                                                                144
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                10
# first_review                                                             2017-09-09
# last_review                                                              2018-04-25
# review_scores_rating                                                             82
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                            8
# review_scores_value                                                               8
# requires_license                                                                  t
# license                                                   City Registration Pending
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  t
# is_business_travel_ready                                                          f
# cancellation_policy                                     strict_14_with_grace_period
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    6
# reviews_per_month                                                                 1
#
#                                                                                3608  \
# id                                                                         20635128
# listing_url                                   https://www.airbnb.com/rooms/20635128
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                    Calling all techies/stay at a hacker house!
# summary                           Welcome to hacker/co-living house for entrepre...
# space                             This specific room with the twin beds has 2 be...
# description                       Welcome to hacker/co-living house for entrepre...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/d9eca351-d...
# xl_picture_url                                                                  NaN
# host_id                                                                    21940642
# host_url                                 https://www.airbnb.com/users/show/21940642
# host_name                                                                      Alex
# host_since                                                               2014-09-29
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                              99%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/pictures/ab026665-a...
# host_picture_url                  https://a0.muscache.com/im/pictures/ab026665-a...
# host_neighbourhood                                                     Mid-Wilshire
# host_listings_count                                                              27
# host_total_listings_count                                                        27
# host_verifications                ['email', 'phone', 'facebook', 'google', 'revi...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Crocker Amazon
# neighbourhood_cleansed                                               Crocker Amazon
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94112
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7114
# longitude                                                                  -122.438
# is_location_exact                                                                 t
# property_type                                                                 House
# room_type                                                               Shared room
# accommodates                                                                      2
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              2
# bed_type                                                                   Real Bed
# amenities                         {Wifi,"Air conditioning",Kitchen,Heating,Washe...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                              $0.00
# cleaning_fee                                                                  $0.00
# guests_included                                                                   1
# extra_people                                                                 $45.00
# minimum_nights                                                                   30
# maximum_nights                                                                  180
# calendar_updated                                                        2 weeks ago
# has_availability                                                                  t
# availability_30                                                                  15
# availability_60                                                                  45
# availability_90                                                                  75
# availability_365                                                                165
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                 9
# first_review                                                             2017-09-07
# last_review                                                              2018-05-13
# review_scores_rating                                                             80
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         8
# review_scores_checkin                                                             8
# review_scores_communication                                                       8
# review_scores_location                                                            9
# review_scores_value                                                               8
# requires_license                                                                  t
# license                                                   City Registration Pending
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  t
# is_business_travel_ready                                                          f
# cancellation_policy                                     strict_14_with_grace_period
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              0.89
#
#                                                                                3609  \
# id                                                                         20635250
# listing_url                                   https://www.airbnb.com/rooms/20635250
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                                 Hacker house in quiet location
# summary                           Welcome to hacker/co-living house for entrepre...
# space                             This specific room with the twin beds has 2 be...
# description                       Welcome to hacker/co-living house for entrepre...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/c9c10d2c-0...
# xl_picture_url                                                                  NaN
# host_id                                                                    21940642
# host_url                                 https://www.airbnb.com/users/show/21940642
# host_name                                                                      Alex
# host_since                                                               2014-09-29
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                              99%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/pictures/ab026665-a...
# host_picture_url                  https://a0.muscache.com/im/pictures/ab026665-a...
# host_neighbourhood                                                     Mid-Wilshire
# host_listings_count                                                              27
# host_total_listings_count                                                        27
# host_verifications                ['email', 'phone', 'facebook', 'google', 'revi...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Crocker Amazon
# neighbourhood_cleansed                                               Crocker Amazon
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94112
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7115
# longitude                                                                  -122.439
# is_location_exact                                                                 t
# property_type                                                                 House
# room_type                                                               Shared room
# accommodates                                                                      2
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              2
# bed_type                                                                   Real Bed
# amenities                         {Wifi,"Air conditioning",Kitchen,Heating,Washe...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                              $0.00
# cleaning_fee                                                                  $0.00
# guests_included                                                                   1
# extra_people                                                                 $45.00
# minimum_nights                                                                   30
# maximum_nights                                                                  180
# calendar_updated                                                        3 weeks ago
# has_availability                                                                  t
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                  18
# availability_365                                                                108
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                12
# first_review                                                             2017-09-05
# last_review                                                              2018-05-29
# review_scores_rating                                                             85
# review_scores_accuracy                                                            8
# review_scores_cleanliness                                                         7
# review_scores_checkin                                                            10
# review_scores_communication                                                       9
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                   City Registration Pending
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  t
# is_business_travel_ready                                                          f
# cancellation_policy                                     strict_14_with_grace_period
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              1.18
#
#                                                                                3615
# id                                                                         20652378
# listing_url                                   https://www.airbnb.com/rooms/20652378
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                                        World traveler coliving
# summary                           Welcome to hacker/co-living house for entrepre...
# space                             This specific room with the twin beds has 2 be...
# description                       Welcome to hacker/co-living house for entrepre...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                                                                   NaN
# medium_url                                                                      NaN
# picture_url                       https://a0.muscache.com/im/pictures/bd835a6a-2...
# xl_picture_url                                                                  NaN
# host_id                                                                    21940642
# host_url                                 https://www.airbnb.com/users/show/21940642
# host_name                                                                      Alex
# host_since                                                               2014-09-29
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                              99%
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/pictures/ab026665-a...
# host_picture_url                  https://a0.muscache.com/im/pictures/ab026665-a...
# host_neighbourhood                                                     Mid-Wilshire
# host_listings_count                                                              27
# host_total_listings_count                                                        27
# host_verifications                ['email', 'phone', 'facebook', 'google', 'revi...
# host_has_profile_pic                                                              t
# host_identity_verified                                                            t
# street                                             San Francisco, CA, United States
# neighbourhood                                                        Crocker Amazon
# neighbourhood_cleansed                                               Crocker Amazon
# neighbourhood_group_cleansed                                                    NaN
# city                                                                  San Francisco
# state                                                                            CA
# zipcode                                                                       94112
# market                                                                San Francisco
# smart_location                                                    San Francisco, CA
# country_code                                                                     US
# country                                                               United States
# latitude                                                                    37.7121
# longitude                                                                  -122.439
# is_location_exact                                                                 t
# property_type                                                                 House
# room_type                                                               Shared room
# accommodates                                                                      2
# bathrooms                                                                         1
# bedrooms                                                                          1
# beds                                                                              2
# bed_type                                                                   Real Bed
# amenities                         {Wifi,"Air conditioning",Kitchen,Heating,Washe...
# square_feet                                                                     NaN
# price                                                                         $0.00
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                              $0.00
# cleaning_fee                                                                  $0.00
# guests_included                                                                   1
# extra_people                                                                 $45.00
# minimum_nights                                                                   30
# maximum_nights                                                                  180
# calendar_updated                                                        3 weeks ago
# has_availability                                                                  t
# availability_30                                                                   0
# availability_60                                                                  10
# availability_90                                                                  40
# availability_365                                                                130
# calendar_last_scraped                                                    2018-07-05
# number_of_reviews                                                                10
# first_review                                                             2017-09-19
# last_review                                                              2018-05-27
# review_scores_rating                                                             83
# review_scores_accuracy                                                            8
# review_scores_cleanliness                                                         8
# review_scores_checkin                                                             9
# review_scores_communication                                                       9
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                   City Registration Pending
# jurisdiction_names                                                {"SAN FRANCISCO"}
# instant_bookable                                                                  t
# is_business_travel_ready                                                          f
# cancellation_policy                                     strict_14_with_grace_period
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    6
# reviews_per_month                                                              1.03

# %%
listd['host_is_superhost'] = (listd['host_is_superhost'] == True).astype(int)
listd['host_identity_verified'] = (listd['host_identity_verified'] == True).astype(int)
listd['bed_type'] = (listd['bed_type'] == True).astype(int)

# %%
y=listd.price
X=listd.copy()
X=X.drop(['price'],axis=1)

# %%
# X=dflreg.drop([listd_insig_cols],axis=1)
# listd.drop(listd_drop_cols,axis=1,inplace=True )

# %%
X_chunk, X_test, y_chunk, y_test = train_test_split(X, y, test_size=0.20, random_state=47)
X_train, X_vald, y_train, y_vald = train_test_split(X_chunk, y_chunk, test_size=0.20, random_state=47)

# %%
X_train = X_chunk.copy()
y_train = y_chunk.copy()

# %%
print(X_train.shape, X_vald.shape, X_test.shape)
print(y_train.shape, y_vald.shape, y_test.shape)
# Out:
# (3729, 49) (746, 49) (933, 49)
# (3729,) (746,) (933,)

# %%
X_train.head()
# Out:
#       host_is_superhost  host_identity_verified  accommodates  bathrooms  \
# 3884                  0                       0             4        1.0
# 3945                  0                       0             8        3.0
# 3908                  0                       1             2        1.0
# 2273                  1                       1             2        1.0
# 3473                  0                       0             6        1.0
#
#       bedrooms  beds  bed_type  cleaning_fee  guests_included  room_type_full  \
# 3884         1   1.0         1          35.0                1               1
# 3945         5   6.0         1         200.0                8               1
# 3908         1   1.0         1          80.0                1               1
# 2273         1   1.0         1          50.0                1               0
# 3473         1   3.0         1           0.0                1               0
#
#            ...         zipcode_94122.0  zipcode_94123.0  zipcode_94124.0  \
# 3884       ...                       0                0                0
# 3945       ...                       0                0                0
# 3908       ...                       0                0                0
# 2273       ...                       0                0                0
# 3473       ...                       0                1                0
#
#       zipcode_94127.0  zipcode_94129.0  zipcode_94131.0  zipcode_94132.0  \
# 3884                0                0                0                0
# 3945                0                0                0                0
# 3908                0                0                0                0
# 2273                0                0                0                0
# 3473                0                0                0                0
#
#       zipcode_94133.0  zipcode_94134.0  zipcode_94158.0
# 3884                0                0                0
# 3945                0                0                0
# 3908                0                0                0
# 2273                0                0                0
# 3473                0                0                0
#
# [5 rows x 49 columns]

# %%
import pickle

X_train.to_pickle('pkls/rand_split/X_train.pkl')
y_train.to_pickle('pkls/rand_split/y_train.pkl')
X_test.to_pickle('pkls/rand_split/X_test.pkl')
y_test.to_pickle('pkls/rand_split/y_test.pkl')

# %%
# X_train._get_numeric_data().info()

# %%
# -------------------------------------------------------

# %%
listd_lt_500=listd[listd.price<500]
listd_gt_500=listd[listd.price>500]

# %%
y=listd_lt_500.price
X=listd_lt_500.copy()
X=X.drop(['price'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=47)

X_train.to_pickle('pkls/price_split/X_lt_train.pkl')
y_train.to_pickle('pkls/price_split/y_lt_train.pkl')
X_test.to_pickle('pkls/price_split/X_lt_test.pkl')
y_test.to_pickle('pkls/price_split/y_lt_test.pkl')


y=listd_gt_500.price
X=listd_gt_500.copy()
X=X.drop(['price'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=47)

X_train.to_pickle('pkls/price_split/X_gt_train.pkl')
y_train.to_pickle('pkls/price_split/y_gt_train.pkl')
X_test.to_pickle('pkls/price_split/X_gt_test.pkl')
y_test.to_pickle('pkls/price_split/y_gt_test.pkl')
