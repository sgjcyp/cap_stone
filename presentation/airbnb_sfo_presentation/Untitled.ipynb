# %%
import pandas as pd
# pd.set_option('display.max_colu?mns', 96)
pd.set_option('display.max_rows', 96)

# %%
purelst = pd.read_csv('listings.csv.gz')

# %%
purelst.head().T
# Out:
#                                                                                   0  \
# id                                                                              958
# listing_url                                        https://www.airbnb.com/rooms/958
# scrape_id                                                            20180705131954
# last_scraped                                                             2018-07-05
# name                                            Bright, Modern Garden Unit - 1BR/1B
# summary                           Our bright garden unit overlooks a grassy back...
# space                             Newly remodeled, modern, and bright garden uni...
# description                       Our bright garden unit overlooks a grassy back...
# experiences_offered                                                            none
# neighborhood_overview             *Quiet cul de sac in friendly neighborhood *St...
# ...

# %%
purelst['price']=purelst['price'].str.replace('$','')
purelst['price']=purelst['price'].str.replace(',','')
purelst['price']=pd.to_numeric(purelst['price'])

# %%
purelst[purelst.price > 500].shape
# Out:
# (247, 96)

# %%
purelst[purelst.price > 1000].shape
# Out:
# (46, 96)

# %%
purelst[purelst.price > 1500].shape
# Out:
# (11, 96)

# %%
purelst[purelst.price > 2000].shape
# Out:
# (7, 96)

# %%
purelst[purelst.price > 3000].shape
# Out:
# (4, 96)

# %%
purelst[purelst.price > 4000].shape
# Out:
# (2, 96)

# %%
purelst[purelst.price > 8000].shape
# Out:
# (1, 96)

# %%
purelst[purelst.price > 8000].shape
